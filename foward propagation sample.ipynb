# %%
import numpy as np
from random import seed

# %%
weights=np.around(np.random.uniform(size=6),decimals=2)
biases=np.around(np.random.uniform(size=3),decimals=2)

# %%
print(weights)
print(biases)
# Out:
# [0.47 0.04 0.08 0.73 0.64 0.03]
# [0.3  0.22 0.06]

# %%
x_1=0.5
x_2=0.85
print('x1 is {} and x2 is {}'.format(x_1,x_2))
# Out:
# x1 is 0.5 and x2 is 0.85

# %%
z_11=x_1*weights[0]+x_2*weights[1]+biases[0]

# %%
z_12 = x_1 * weights[2] + x_2 * weights[3] + biases[1]

# %%
print('weight sum of the imputs at the second node in the hidden layer is {}'.format(np.around(z_11,decimals=4)))
# Out:
# weight sum of the imputs at the second node in the hidden layer is 0.569

# %%
a_11=1.0/(1.0+np.exp(-z_11))
print('a_11 =',a_11)
# Out:
# a_11 = 0.6385323983635313

# %%
a_12 = 1.0 / (1.0 + np.exp(-z_12))

# %%
print('The activation of the second node in the hidden layer is {}'.format(np.around(a_12, decimals=4)))
# Out:
# The activation of the second node in the hidden layer is 0.7069

# %%
z_2=a_11*weights[4]+a_12*weights[5]+biases[2]

# %%
print('The weighted sum of the inputs at the node in the output layer is {}'.format(np.around(z_2, decimals=4)))
# Out:
# The weighted sum of the inputs at the node in the output layer is 0.4899

# %%
a_2=1.0/(1.0+np.exp(-z_2))

# %%
print('The output of the network for x1 = 0.5 and x2 = 0.85 is {}'.format(np.around(a_2, decimals=4)))
# Out:
# The output of the network for x1 = 0.5 and x2 = 0.85 is 0.6201

# %%
n=2
num_hidden_layers=2
m=[2,2]
num_nodes_output=1

# %%
import numpy as np
num_nodes_previous=n
network={}
for layer in range(num_hidden_layers + 1):

    # determine name of layer
    if layer == num_hidden_layers:
        layer_name = 'output'
        num_nodes = num_nodes_output
    else:
        layer_name = 'layer_{}'.format(layer + 1)
        num_nodes = m[layer]

    # initialize weights and biases associated with each node in the current layer
    network[layer_name] = {}
    for node in range(num_nodes):
        node_name = 'node_{}'.format(node+1)
        network[layer_name][node_name] = {
            'weights': np.around(np.random.uniform(size=num_nodes_previous), decimals=2),
            'bias': np.around(np.random.uniform(size=1), decimals=2),
        }

    num_nodes_previous = num_nodes

print(network) # print network
# Out:
# {'layer_1': {'node_1': {'weights': array([0.52, 0.42]), 'bias': array([0.05])}, 'node_2': {'weights': array([0.57, 0.8 ]), 'bias': array([0.11])}}, 'layer_2': {'node_1': {'weights': array([0.28, 0.64]), 'bias': array([0.49])}, 'node_2': {'weights': array([0.51, 0.46]), 'bias': array([0.89])}}, 'output': {'node_1': {'weights': array([0.61, 0.6 ]), 'bias': array([0.44])}}}

# %%
def initialize_network(num_inputs, num_hidden_layers, num_nodes_hidden, num_nodes_output):
    num_nodes_previous=num_inputs
    network={}
    for layer in range(num_hidden_layers+1):
        if layer == num_hidden_layers:
            layer_name = 'output'
            num_nodes = num_nodes_output
        else:
            layer_name = 'layer_{}'.format(layer + 1)
            num_nodes = num_nodes_hidden[layer]
        network[layer_name] = {}
        for node in range(num_nodes):
            node_name = 'node_{}'.format(node+1)
            network[layer_name][node_name] = {
                'weights': np.around(np.random.uniform(size=num_nodes_previous), decimals=2),
                "bias": np.around(np.random.uniform(size=1), decimals=2),
            }
        num_nodes_previous = num_nodes
    return network

# %%
small_network=initialize_network(5,3,[3,2,3],1)

# %%
def compute_weighted_sum(inputs,weigths,bias):
    return np.sum(inputs*weigths)+bias

# %%
np.random.seed(12)
inputs=np.around(np.random.uniform(size=5),decimals=2)
print('the input to the network are {}'.format(inputs))
# Out:
# the input to the network are [0.15 0.74 0.26 0.53 0.01]

# %%
nodes_weights=small_network['layer_1']['node_1']['weights']
node_bias=small_network['layer_1']['node_1']['bias']
weighted_sum=compute_weighted_sum(inputs,nodes_weights,node_bias)
print('the weight sum at the fist node in the hidden layer is {}'.format(weighted_sum[0],decimals=4))
# Out:
# the weight sum at the fist node in the hidden layer is 1.8840999999999997

# %%
def node_activation(weighted_sum):
    return 1.0/(1.0+np.exp(-weighted_sum))

# %%
node_output=node_activation(compute_weighted_sum(inputs,nodes_weights,node_bias))
print('the output of the network layer is {}'.format(np.around(node_output,decimals=4)))
# Out:
# the output of the network layer is [0.8681]

# %%
def forward_propagate(network, inputs):

    layer_inputs = list(inputs) # start with the input layer as the input to the first hidden layer

    for layer in network:

        layer_data = network[layer]

        layer_outputs = []
        for layer_node in layer_data:

            node_data = layer_data[layer_node]

            # compute the weighted sum and the output of each node at the same time
            node_output = node_activation(compute_weighted_sum(layer_inputs, node_data['weights'], node_data['bias']))
            layer_outputs.append(np.around(node_output[0], decimals=4))

        if layer != 'output':
            print('The outputs of the nodes in hidden layer number {} is {}'.format(layer.split('_')[1], layer_outputs))

        layer_inputs = layer_outputs # set the output of this layer to be the input to next layer

    network_predictions = layer_outputs
    return network_predictions

# %%
predictions=forward_propagate(small_network,inputs)
print('the predicted value by tge network is {}'.format(np.around(predictions,decimals=4)))
# Out:
# The outputs of the nodes in hidden layer number 1 is [np.float64(0.8681), np.float64(0.8295), np.float64(0.803)]
# The outputs of the nodes in hidden layer number 2 is [np.float64(0.9425), np.float64(0.9039)]
# The outputs of the nodes in hidden layer number 3 is [np.float64(0.7267), np.float64(0.8477), np.float64(0.7605)]
# the predicted value by tge network is [0.7961]

# %%
my_network=initialize_network(5,3,[2,3,2],3)

# %%
inputs=np.around(np.random.uniform(size=5),decimals=2)

# %%
predictions=forward_propagate(my_network,inputs)
print('the predicted value by tge network is {}'.format(np.around(predictions,decimals=4)))
# Out:
# The outputs of the nodes in hidden layer number 1 is [np.float64(0.8857), np.float64(0.8889)]
# The outputs of the nodes in hidden layer number 2 is [np.float64(0.7822), np.float64(0.6965), np.float64(0.7411)]
# The outputs of the nodes in hidden layer number 3 is [np.float64(0.868), np.float64(0.881)]
# the predicted value by tge network is [0.8952 0.8222 0.8035]
